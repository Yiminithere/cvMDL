# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rc
from statsmodels.distributions.empirical_distribution import ECDF
from multifidelity.dl import MFDistributionLearning
from utils.utils import cdf_inverse

# %% [markdown]
# ## Load data

# %%
df1 = pd.read_csv('./data/exploration_output.csv').loc[1:].to_numpy()[:,1:]
df2 = pd.read_csv('./data/exploitation_output.csv').loc[1:].to_numpy()[:,1:]
df_full_fixed = np.vstack((df1, df2))/1e6

# %% [markdown]
# ## Simulation

# %%
import os
import random as random

## results holder
# cvMDL
cvMDL_l2 = [] # overall L^2 error
cvMDL_var = [] # 0.99-VaR   
cvMDL_cvar = [] # 0.99-CVaR
cvMDL_cvar2 = [] # 0.95-CVaR
cvMDL_mean = [] # mean
cvMDL_sd = [] # standard deviation

# ecdf
ecdf_l2 = []
ecdf_var = []
ecdf_cvar = []
ecdf_cvar2 = []
ecdf_mean = []
ecdf_sd = []

# oracle
oracle_var = []
oracle_cvar = []
oracle_cvar2 = []
oracle_mean = []
oracle_sd = []


# cvMDL input parameters
cost = [9.1,1.3,1.1,1,108.9]
tol_size = 4
budget = 50*1e3
# total number of simulations
N = 100
# maximum number of exploration samples
#m = int(budget/cost[-1])
m = 500
random.seed(1234567891)
randseed = random.sample(range(10000), N)

foldername = f'result_{budget}'
if not os.path.exists(foldername):
    os.makedirs(foldername)
else:
    print("Folder already exists.")
    
# VaR/CVaR and moment parameters
alpha = 0.99
alpha2 = 0.95
# interval for CVaR computation
I = np.linspace(alpha,1-1e-8,5000)
# interval for moment statistics
I2 = np.linspace(alpha2,1-1e-8,5000)
# interval for moment statistics
II = np.linspace(1e-8,1-1e-8,5000)
# interval for overall error estimation
III = np.linspace(1.9,2.8,5000)
cvMDL_exp = 0

for i in range(N):
#    i = 99
    print('i =', i)
    # randomly divide data into exploration and exploitation
    np.random.seed(randseed[i])
    S = np.random.permutation(df_full_fixed.shape[0])
    df_full = df_full_fixed[S,:]
    df_low = {i+1: df_full[:,i:(i+1)][:m,:] for i in range(4)}
    df_high = df_full[:,4:5][:m,:]
    df_tt = {i+1: df_full[:,i:(i+1)][m:,:] for i in range(4)}
    
    # compute oracle CDF (no more randomseed is needed here)
    y_oracle = ECDF(df_full[:,-1][m:]) 
    y_oracle_inv = cdf_inverse(y_oracle, interpolation = True, interval = [min(df_full[:,-1][m:]), max(df_full[:,-1][m:])])
    
    # cvMDL exploration
    a = MFDistributionLearning()
    cvMDL_res = a.cvMDL(df_low, df_high, cost, tol_size, budget)
    print('cvMDL: {}'.format({key: value for key, value in cvMDL_res.items() if key in ['model','exp_rate', 'sample_rate']}))
    cvMDL_exp = cvMDL_exp + cvMDL_res['exp_rate']
    
    # naive ecdf using high-fidelity samples only
    ecdf = ECDF(df_high.flatten()[:int(budget/cost[-1])])
    ecdf_inv = cdf_inverse(ecdf, interpolation = True, interval = [min(df_high.flatten()[:int(budget/cost[-1])]),\
                                                                   max(df_high.flatten()[:int(budget/cost[-1])])])
    
    # cvMDL exploitation
    cvMDL_exploit = a.ecdf_cv_1d(df_tt, cvMDL_res, inverse = True)
    cvMDL_cdf = cvMDL_exploit['cdf']
    cvMDL_cdf_inv = cvMDL_exploit['quantile']
    
    # compute mean errors
    cvMDL_l2.append(np.sum((y_oracle(III)-np.array([cvMDL_cdf(x) for x in III]))**2)*(III[1]-III[0]))
    ecdf_l2.append(np.sum((y_oracle(III)-ecdf(III))**2)*(III[1]-III[0]))
    print('L2 error: {}'.format({key: value for key, value in zip(['cvMLD', 'ecdf'], [cvMDL_l2[-1], ecdf_l2[-1]])}))
    
    # compute VaR/CVaR
    oracle_var.append(y_oracle_inv(alpha))
    cvMDL_var.append(cvMDL_cdf_inv(alpha))
    ecdf_var.append(ecdf_inv(alpha))
    print('VaR: {}'.format({key: value for key, value in zip(['oracle','cvMLD', 'ecdf'], [oracle_var[-1], cvMDL_var[-1], ecdf_var[-1]])}))
    
    oracle_cvar.append(np.sum(np.array([y_oracle_inv(x) for x in I])*(I[1]-I[0]))/(1-alpha))
    cvMDL_cvar.append(np.sum(np.array([cvMDL_cdf_inv(x) for x in I])*(I[1]-I[0]))/(1-alpha))
    ecdf_cvar.append(np.sum(np.array([ecdf_inv(x) for x in I])*(I[1]-I[0]))/(1-alpha))
    print('CVaR: {}'.format({key: value for key, value in zip(['oracle','cvMLD', 'ecdf'], [oracle_cvar[-1],cvMDL_cvar[-1], ecdf_cvar[-1]])}))
    
    oracle_cvar2.append(np.sum(np.array([y_oracle_inv(x) for x in I2])*(I2[1]-I2[0]))/(1-alpha2))
    cvMDL_cvar2.append(np.sum(np.array([cvMDL_cdf_inv(x) for x in I2])*(I2[1]-I2[0]))/(1-alpha2))
    ecdf_cvar2.append(np.sum(np.array([ecdf_inv(x) for x in I2])*(I2[1]-I2[0]))/(1-alpha2))
    print('CVaR2: {}'.format({key: value for key, value in zip(['oracle','cvMLD', 'ecdf'], [oracle_cvar2[-1],cvMDL_cvar2[-1], ecdf_cvar2[-1]])}))
    
    # compute moment statistics
    # inverse sampling
    oracle_dt = df_full[:,-1][m:]
    cvMDL_dt = np.array([cvMDL_cdf_inv(x) for x in II])
    ecdf_dt = df_high.flatten()[:int(budget/cost[-1])]
    # mean
    oracle_mean.append(np.mean(oracle_dt))
    cvMDL_mean.append(np.mean(cvMDL_dt))
    ecdf_mean.append(np.mean(ecdf_dt))
    print('mean: {}'.format({key: value for key, value in zip(['oracle','cvMLD', 'ecdf'], [oracle_mean[-1],cvMDL_mean[-1], ecdf_mean[-1]])}))
    # standard deviation
    oracle_sd.append(np.std(oracle_dt))
    cvMDL_sd.append(np.std(cvMDL_dt))
    ecdf_sd.append(np.std(ecdf_dt))
    print('std: {}'.format({key: value for key, value in zip(['oracle','cvMLD', 'ecdf'], [oracle_sd[-1],cvMDL_sd[-1], ecdf_sd[-1]])}))
    print('-------------------------------------------------------------------------------------------------------------')
    print('-------------------------------------------------------------------------------------------------------------')
# Out:
# Folder already exists.
# i = 0
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 8.465465444376358e-05, 'ecdf': 0.00037176186718651446}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.64503744), 'ecdf': array(2.64337159)}
# CVaR: {'oracle': 2.683209082231531, 'cvMLD': 2.673615163720145, 'ecdf': 2.6735415650550527}
# CVaR2: {'oracle': 2.6218956397591024, 'cvMLD': 2.6204993818485445, 'ecdf': 2.62100900204143}
# mean: {'oracle': 2.3486221860407084, 'cvMLD': 2.3467806898241923, 'ecdf': 2.3514576296005414}
# std: {'oracle': 0.13440507662804893, 'cvMLD': 0.1335870535411284, 'ecdf': 0.12563637561677996}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 1
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 0.00013525347052528912, 'ecdf': 0.000147858873545726}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.6607825), 'ecdf': array(2.65000953)}
# CVaR: {'oracle': 2.681664288264884, 'cvMLD': 2.682383903192354, 'ecdf': 2.686912742038434}
# CVaR2: {'oracle': 2.620221210478647, 'cvMLD': 2.626691987811114, 'ecdf': 2.628349323059938}
# mean: {'oracle': 2.348712979521345, 'cvMLD': 2.348481592626909, 'ecdf': 2.344956214695809}
# std: {'oracle': 0.1331947814620301, 'cvMLD': 0.13947056225270554, 'ecdf': 0.13952336278169833}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 2
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 6.642669634240244e-05, 'ecdf': 0.00010770623053156549}
# VaR: {'oracle': array(2.65008955), 'cvMLD': array(2.67056572), 'ecdf': array(2.67167769)}
# CVaR: {'oracle': 2.6812791874953237, 'cvMLD': 2.6867888894251286, 'ecdf': 2.685137000127051}
# CVaR2: {'oracle': 2.620323990587421, 'cvMLD': 2.6330158153532057, 'ecdf': 2.635072261994407}
# mean: {'oracle': 2.34884662366065, 'cvMLD': 2.3514774988931793, 'ecdf': 2.3478859330440534}
# std: {'oracle': 0.13327224110235883, 'cvMLD': 0.13627281522990994, 'ecdf': 0.1396958471133251}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 3
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 7.756968530053533e-05, 'ecdf': 0.00012909744225146364}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.64032141), 'ecdf': array(2.63391251)}
# CVaR: {'oracle': 2.6829656012169902, 'cvMLD': 2.6601493733205634, 'ecdf': 2.652603904112492}
# CVaR2: {'oracle': 2.6215560203245385, 'cvMLD': 2.616822694466106, 'ecdf': 2.6142678985703727}
# mean: {'oracle': 2.348034318724706, 'cvMLD': 2.349698061811692, 'ecdf': 2.354117321716076}
# std: {'oracle': 0.1336623206421145, 'cvMLD': 0.13350956554634477, 'ecdf': 0.1333206432127799}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 4
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 6.111719125990871e-05, 'ecdf': 5.2366316366035074e-05}
# VaR: {'oracle': array(2.65120371), 'cvMLD': array(2.64405546), 'ecdf': array(2.67358178)}
# CVaR: {'oracle': 2.6806916161138283, 'cvMLD': 2.6748222091704936, 'ecdf': 2.6982672292098826}
# CVaR2: {'oracle': 2.6216570099401735, 'cvMLD': 2.6142826640546972, 'ecdf': 2.6238619120985693}
# mean: {'oracle': 2.3484260419359497, 'cvMLD': 2.348498964025969, 'ecdf': 2.3510324737339636}
# std: {'oracle': 0.13375159680260545, 'cvMLD': 0.13018243747601932, 'ecdf': 0.13409423735144313}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 5
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 0.00010165672308228643, 'ecdf': 0.00014587037495910607}
# VaR: {'oracle': array(2.65160713), 'cvMLD': array(2.63802759), 'ecdf': array(2.65600524)}
# CVaR: {'oracle': 2.6807340242681934, 'cvMLD': 2.6758059975857225, 'ecdf': 2.7041652418542137}
# CVaR2: {'oracle': 2.6207307935898916, 'cvMLD': 2.6162842872585643, 'ecdf': 2.629418727923288}
# mean: {'oracle': 2.3487454280339795, 'cvMLD': 2.3467347508767618, 'ecdf': 2.3455166585199265}
# std: {'oracle': 0.13398937041361764, 'cvMLD': 0.13509544158948203, 'ecdf': 0.13086986096012176}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 6
# cvMDL: {'exp_rate': 353, 'model': [2, 4], 'sample_rate': 3106}
# L2 error: {'cvMLD': 0.00014262803524791632, 'ecdf': 0.00012470831511252926}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.64028315), 'ecdf': array(2.63787883)}
# CVaR: {'oracle': 2.68311809711791, 'cvMLD': 2.6577003406098516, 'ecdf': 2.671057881659062}
# CVaR2: {'oracle': 2.622351974403848, 'cvMLD': 2.6127044732503277, 'ecdf': 2.6151329834980523}
# mean: {'oracle': 2.3490024689174915, 'cvMLD': 2.343518348926613, 'ecdf': 2.3451611944325568}
# std: {'oracle': 0.13396410399378625, 'cvMLD': 0.13321471300661644, 'ecdf': 0.13113903063725713}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 7
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 7.222257073552247e-05, 'ecdf': 0.00021619766727733807}
# VaR: {'oracle': array(2.65008955), 'cvMLD': array(2.64922465), 'ecdf': array(2.71465567)}
# CVaR: {'oracle': 2.675519891751071, 'cvMLD': 2.6899866219636386, 'ecdf': 2.731313246006382}
# CVaR2: {'oracle': 2.618646858387735, 'cvMLD': 2.6286170669188635, 'ecdf': 2.6512699851564467}
# mean: {'oracle': 2.3485162365008465, 'cvMLD': 2.3512808859424776, 'ecdf': 2.3494479327303597}
# std: {'oracle': 0.13288723418630782, 'cvMLD': 0.13497323600515912, 'ecdf': 0.14253740705095938}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 8
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 0.00011287625482046271, 'ecdf': 0.00018632831321305126}
# VaR: {'oracle': array(2.65405706), 'cvMLD': array(2.63488071), 'ecdf': array(2.6399484)}
# CVaR: {'oracle': 2.6833932212967833, 'cvMLD': 2.661277285337174, 'ecdf': 2.65059949640038}
# CVaR2: {'oracle': 2.6216245799025417, 'cvMLD': 2.6106354288203044, 'ecdf': 2.6163904146752013}
# mean: {'oracle': 2.347899861814343, 'cvMLD': 2.345820747102126, 'ecdf': 2.3553932689697654}
# std: {'oracle': 0.13350236625503906, 'cvMLD': 0.13502975712180362, 'ecdf': 0.13557143407456185}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 9
# cvMDL: {'exp_rate': 347, 'model': [2, 4], 'sample_rate': 3423}
# L2 error: {'cvMLD': 9.597194096142467e-05, 'ecdf': 0.00021802788364964912}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.64720317), 'ecdf': array(2.65143848)}
# CVaR: {'oracle': 2.683011484054742, 'cvMLD': 2.671044752817658, 'ecdf': 2.676799162073764}
# CVaR2: {'oracle': 2.6200675530266024, 'cvMLD': 2.627283161569467, 'ecdf': 2.636768404463319}
# mean: {'oracle': 2.34843230182069, 'cvMLD': 2.3494630189715267, 'ecdf': 2.3530974718961737}
# std: {'oracle': 0.13287564417868433, 'cvMLD': 0.13811928428513875, 'ecdf': 0.14115891250276744}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 10
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 8.02700478290638e-05, 'ecdf': 0.00017174226432017107}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.64351442), 'ecdf': array(2.65210046)}
# CVaR: {'oracle': 2.6837005315465454, 'cvMLD': 2.6706044678718577, 'ecdf': 2.668563509603643}
# CVaR2: {'oracle': 2.621886401080147, 'cvMLD': 2.614995843977228, 'ecdf': 2.619010189799583}
# mean: {'oracle': 2.3491565900615368, 'cvMLD': 2.3458155313384643, 'ecdf': 2.3418648419085293}
# std: {'oracle': 0.13349974069234452, 'cvMLD': 0.13345043023999764, 'ecdf': 0.13613885901124978}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 11
# cvMDL: {'exp_rate': 346, 'model': [2, 4], 'sample_rate': 3476}
# L2 error: {'cvMLD': 8.386632138494214e-05, 'ecdf': 5.063000226808143e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.63669084), 'ecdf': array(2.62773383)}
# CVaR: {'oracle': 2.6826167352452877, 'cvMLD': 2.6582546350778844, 'ecdf': 2.6752427694446963}
# CVaR2: {'oracle': 2.622682533383439, 'cvMLD': 2.6103890005973085, 'ecdf': 2.6097181859831453}
# mean: {'oracle': 2.3485661343419197, 'cvMLD': 2.351832740489803, 'ecdf': 2.350850871165566}
# std: {'oracle': 0.1339665237383523, 'cvMLD': 0.13226230155897534, 'ecdf': 0.13129088558635543}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 12
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 3.486230025175343e-05, 'ecdf': 0.00024200575722628696}
# VaR: {'oracle': array(2.65426766), 'cvMLD': array(2.64046625), 'ecdf': array(2.63733259)}
# CVaR: {'oracle': 2.6845768942593717, 'cvMLD': 2.672292144528901, 'ecdf': 2.652219335674595}
# CVaR2: {'oracle': 2.622414580727774, 'cvMLD': 2.6283893518876633, 'ecdf': 2.614988235118556}
# mean: {'oracle': 2.3480398731133456, 'cvMLD': 2.348566193745188, 'ecdf': 2.3558633892876113}
# std: {'oracle': 0.13405316141184226, 'cvMLD': 0.13438603528564289, 'ecdf': 0.12971078875611458}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 13
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 4.406887634364073e-05, 'ecdf': 0.0001057209295503859}
# VaR: {'oracle': array(2.65036809), 'cvMLD': array(2.66022704), 'ecdf': array(2.67158802)}
# CVaR: {'oracle': 2.680995573640815, 'cvMLD': 2.6853525837188603, 'ecdf': 2.691915405364033}
# CVaR2: {'oracle': 2.6199989560278474, 'cvMLD': 2.622153668074956, 'ecdf': 2.6390155037511573}
# mean: {'oracle': 2.347984250190887, 'cvMLD': 2.349401458301806, 'ecdf': 2.353963049119474}
# std: {'oracle': 0.13335628655099044, 'cvMLD': 0.1336890222126715, 'ecdf': 0.13680566317719953}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 14
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 4.058718276460147e-05, 'ecdf': 0.00011788701478023536}
# VaR: {'oracle': array(2.65134298), 'cvMLD': array(2.66983624), 'ecdf': array(2.65435989)}
# CVaR: {'oracle': 2.6829852464514357, 'cvMLD': 2.6832623175566344, 'ecdf': 2.67689944160341}
# CVaR2: {'oracle': 2.6211680498058416, 'cvMLD': 2.617376835455033, 'ecdf': 2.6269223617030755}
# mean: {'oracle': 2.3485547668037166, 'cvMLD': 2.348147299975231, 'ecdf': 2.3510655457167196}
# std: {'oracle': 0.13346479736789557, 'cvMLD': 0.1348422151533156, 'ecdf': 0.13814409659159715}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 15
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 9.133395963147066e-05, 'ecdf': 0.00012987734034408628}
# VaR: {'oracle': array(2.65120371), 'cvMLD': array(2.64067298), 'ecdf': array(2.65838624)}
# CVaR: {'oracle': 2.681512917437324, 'cvMLD': 2.680689321423258, 'ecdf': 2.6936035369149893}
# CVaR2: {'oracle': 2.6218902046282144, 'cvMLD': 2.6105393568493716, 'ecdf': 2.6131054106653595}
# mean: {'oracle': 2.3486436616404816, 'cvMLD': 2.352500169239346, 'ecdf': 2.3475461912131528}
# std: {'oracle': 0.1342045796999226, 'cvMLD': 0.1308191342812752, 'ecdf': 0.12597457993900038}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 16
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 7.419597889605928e-05, 'ecdf': 0.0001174046822359869}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.62230724), 'ecdf': array(2.62847717)}
# CVaR: {'oracle': 2.6837865133586627, 'cvMLD': 2.6387259444841615, 'ecdf': 2.661737680409064}
# CVaR2: {'oracle': 2.622329597442563, 'cvMLD': 2.607853639471647, 'ecdf': 2.610201735081765}
# mean: {'oracle': 2.348300708315667, 'cvMLD': 2.3505842676752926, 'ecdf': 2.3540730359173625}
# std: {'oracle': 0.13391491917614934, 'cvMLD': 0.13077191434726734, 'ecdf': 0.1301314886713839}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 17
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 8.764329642210385e-05, 'ecdf': 0.00014626001957236898}
# VaR: {'oracle': array(2.65426766), 'cvMLD': array(2.64962975), 'ecdf': array(2.61905178)}
# CVaR: {'oracle': 2.68459208738106, 'cvMLD': 2.6801391720123457, 'ecdf': 2.6376532432183946}
# CVaR2: {'oracle': 2.623557232718283, 'cvMLD': 2.6239215089094814, 'ecdf': 2.595592709761461}
# mean: {'oracle': 2.349140843081611, 'cvMLD': 2.3503262134086915, 'ecdf': 2.3444786351107236}
# std: {'oracle': 0.13422303467841626, 'cvMLD': 0.1351835103751047, 'ecdf': 0.1259429216710462}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 18
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 5.2369707511951064e-05, 'ecdf': 4.180135454387758e-05}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.65065044), 'ecdf': array(2.64385256)}
# CVaR: {'oracle': 2.6839081020729605, 'cvMLD': 2.6722272517608845, 'ecdf': 2.6649547939109013}
# CVaR2: {'oracle': 2.622548764715989, 'cvMLD': 2.6200470209469318, 'ecdf': 2.611946871244782}
# mean: {'oracle': 2.3488438926838153, 'cvMLD': 2.349608038282941, 'ecdf': 2.3466403453385034}
# std: {'oracle': 0.1339780880111819, 'cvMLD': 0.13017256680046155, 'ecdf': 0.13161230206235844}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 19
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 7.015261733416456e-05, 'ecdf': 7.124481969081477e-05}
# VaR: {'oracle': array(2.65036809), 'cvMLD': array(2.65074053), 'ecdf': array(2.67334246)}
# CVaR: {'oracle': 2.6781536815771534, 'cvMLD': 2.67880505056074, 'ecdf': 2.7249133963788883}
# CVaR2: {'oracle': 2.620097004925571, 'cvMLD': 2.6149512604385037, 'ecdf': 2.641622138883371}
# mean: {'oracle': 2.348305026558951, 'cvMLD': 2.3509196089953095, 'ecdf': 2.3539802184628873}
# std: {'oracle': 0.13368134979775348, 'cvMLD': 0.13224524663493956, 'ecdf': 0.1345623903258712}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 20
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 0.00013059107330061633, 'ecdf': 0.00014581106823911296}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.65588313), 'ecdf': array(2.64833984)}
# CVaR: {'oracle': 2.6839689010030177, 'cvMLD': 2.678595362668369, 'ecdf': 2.6651735644227115}
# CVaR2: {'oracle': 2.62214549327388, 'cvMLD': 2.6193169287558047, 'ecdf': 2.6118874509453547}
# mean: {'oracle': 2.3490551795079258, 'cvMLD': 2.346571421283095, 'ecdf': 2.344652542294878}
# std: {'oracle': 0.13415484476375625, 'cvMLD': 0.1343999912302035, 'ecdf': 0.12857888096509906}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 21
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 0.00011642298424851876, 'ecdf': 0.0001095739992737585}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.60965324), 'ecdf': array(2.61510183)}
# CVaR: {'oracle': 2.6834067070092655, 'cvMLD': 2.627728451224956, 'ecdf': 2.6339937517658414}
# CVaR2: {'oracle': 2.6230906046113, 'cvMLD': 2.6008033559766672, 'ecdf': 2.594057329719384}
# mean: {'oracle': 2.3486971374752836, 'cvMLD': 2.3507200082105, 'ecdf': 2.347705326592438}
# std: {'oracle': 0.13390515012391468, 'cvMLD': 0.12933958767940162, 'ecdf': 0.12838584821361923}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 22
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 6.951069941802865e-05, 'ecdf': 0.0014275581149453967}
# VaR: {'oracle': array(2.65050736), 'cvMLD': array(2.65898043), 'ecdf': array(2.66439345)}
# CVaR: {'oracle': 2.6799608392757506, 'cvMLD': 2.676133523692858, 'ecdf': 2.7091066526360588}
# CVaR2: {'oracle': 2.6197503020231983, 'cvMLD': 2.626809986995047, 'ecdf': 2.640580178507047}
# mean: {'oracle': 2.346763397931648, 'cvMLD': 2.3500910484656283, 'ecdf': 2.372201085603984}
# std: {'oracle': 0.13334408910797227, 'cvMLD': 0.13445557248118864, 'ecdf': 0.1358492474383911}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 23
# cvMDL: {'exp_rate': 353, 'model': [2, 4], 'sample_rate': 3106}
# L2 error: {'cvMLD': 0.00018771605356774574, 'ecdf': 0.0003851820992927568}
# VaR: {'oracle': array(2.65426766), 'cvMLD': array(2.62143548), 'ecdf': array(2.62168955)}
# CVaR: {'oracle': 2.6834524030770717, 'cvMLD': 2.6620236265970845, 'ecdf': 2.658983147623228}
# CVaR2: {'oracle': 2.6229346937552123, 'cvMLD': 2.6086050268626857, 'ecdf': 2.6088230176754146}
# mean: {'oracle': 2.347704055481705, 'cvMLD': 2.351581119263149, 'ecdf': 2.3584755675771527}
# std: {'oracle': 0.1343219582999895, 'cvMLD': 0.13011893447205344, 'ecdf': 0.12752808757028233}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 24
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 5.14268454179118e-05, 'ecdf': 0.00012088812252858675}
# VaR: {'oracle': array(2.65468547), 'cvMLD': array(2.62135421), 'ecdf': array(2.62310273)}
# CVaR: {'oracle': 2.6843222877538957, 'cvMLD': 2.6511528237578954, 'ecdf': 2.645378939260801}
# CVaR2: {'oracle': 2.6228749126536988, 'cvMLD': 2.60828214117947, 'ecdf': 2.605752888164963}
# mean: {'oracle': 2.34915709148905, 'cvMLD': 2.3472096845730284, 'ecdf': 2.3433549446030244}
# std: {'oracle': 0.13363299999268763, 'cvMLD': 0.13167127706093237, 'ecdf': 0.13453168917122785}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 25
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 5.374268656127762e-05, 'ecdf': 0.00010917353160155372}
# VaR: {'oracle': array(2.65120371), 'cvMLD': array(2.64520514), 'ecdf': array(2.66455341)}
# CVaR: {'oracle': 2.6803262802268017, 'cvMLD': 2.687188837343368, 'ecdf': 2.7062332446293036}
# CVaR2: {'oracle': 2.6206885524288457, 'cvMLD': 2.61913752985747, 'ecdf': 2.6320484554171113}
# mean: {'oracle': 2.348854351922312, 'cvMLD': 2.3467901286314046, 'ecdf': 2.3461866715009916}
# std: {'oracle': 0.13382221939256747, 'cvMLD': 0.13118794889401156, 'ecdf': 0.13144713221933133}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 26
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 0.00012008035158894827, 'ecdf': 0.0001825141026674119}
# VaR: {'oracle': array(2.65168773), 'cvMLD': array(2.63323409), 'ecdf': array(2.64000869)}
# CVaR: {'oracle': 2.6833362549818376, 'cvMLD': 2.6616331465636067, 'ecdf': 2.672047302077304}
# CVaR2: {'oracle': 2.6227296928483788, 'cvMLD': 2.6025777943008395, 'ecdf': 2.6105817389565042}
# mean: {'oracle': 2.348186320496012, 'cvMLD': 2.351749175206386, 'ecdf': 2.353059205352607}
# std: {'oracle': 0.1333785177602228, 'cvMLD': 0.13545211784714445, 'ecdf': 0.13755810442506738}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 27
# cvMDL: {'exp_rate': 347, 'model': [2, 4], 'sample_rate': 3423}
# L2 error: {'cvMLD': 4.563359679235339e-05, 'ecdf': 6.2807823303997e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.63672353), 'ecdf': array(2.63745107)}
# CVaR: {'oracle': 2.6844706141853005, 'cvMLD': 2.661353584658335, 'ecdf': 2.6556549207239546}
# CVaR2: {'oracle': 2.622306556548739, 'cvMLD': 2.6168417006040943, 'ecdf': 2.6139851735493123}
# mean: {'oracle': 2.3482791648009207, 'cvMLD': 2.3500914140491695, 'ecdf': 2.3521813202935697}
# std: {'oracle': 0.1338362798557615, 'cvMLD': 0.1337553123944698, 'ecdf': 0.13209057623904236}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 28
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 6.0211862686874766e-05, 'ecdf': 3.9433826458319424e-05}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.6385457), 'ecdf': array(2.65862467)}
# CVaR: {'oracle': 2.6822563638493393, 'cvMLD': 2.6646267877593224, 'ecdf': 2.685112594690533}
# CVaR2: {'oracle': 2.6215081504079123, 'cvMLD': 2.607212882508574, 'ecdf': 2.6242930222196224}
# mean: {'oracle': 2.3485314210710846, 'cvMLD': 2.348685506498132, 'ecdf': 2.350320955923807}
# std: {'oracle': 0.1338818714496893, 'cvMLD': 0.129456565210013, 'ecdf': 0.13316280553898002}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 29
# cvMDL: {'exp_rate': 353, 'model': [2, 4], 'sample_rate': 3106}
# L2 error: {'cvMLD': 8.138671650460326e-05, 'ecdf': 0.00013995366952801125}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.64452988), 'ecdf': array(2.63766159)}
# CVaR: {'oracle': 2.683573848470364, 'cvMLD': 2.66770496403523, 'ecdf': 2.6606774622192693}
# CVaR2: {'oracle': 2.622610615260269, 'cvMLD': 2.617365456852001, 'ecdf': 2.5982836357408985}
# mean: {'oracle': 2.3482444192808707, 'cvMLD': 2.349741372691316, 'ecdf': 2.3518063082564744}
# std: {'oracle': 0.13438950958927456, 'cvMLD': 0.13403690664194814, 'ecdf': 0.12499449666397884}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 30
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 0.00011371511091304045, 'ecdf': 9.370680380631541e-05}
# VaR: {'oracle': array(2.65134298), 'cvMLD': array(2.65150678), 'ecdf': array(2.63847516)}
# CVaR: {'oracle': 2.6838966354018, 'cvMLD': 2.666855473727805, 'ecdf': 2.6608033522999555}
# CVaR2: {'oracle': 2.62163766134498, 'cvMLD': 2.6163244866994315, 'ecdf': 2.614686786971234}
# mean: {'oracle': 2.3486409627984366, 'cvMLD': 2.3434089617695264, 'ecdf': 2.345492610330245}
# std: {'oracle': 0.1337578716863358, 'cvMLD': 0.13456793280390106, 'ecdf': 0.13128112861793148}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 31
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 9.321909106416045e-05, 'ecdf': 7.330929252110598e-05}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.64180281), 'ecdf': array(2.64833798)}
# CVaR: {'oracle': 2.68282923429117, 'cvMLD': 2.681732292808704, 'ecdf': 2.6786847165191365}
# CVaR2: {'oracle': 2.621480461175785, 'cvMLD': 2.624560197416363, 'ecdf': 2.6205676932917488}
# mean: {'oracle': 2.348210442480408, 'cvMLD': 2.350877887880655, 'ecdf': 2.350453875824303}
# std: {'oracle': 0.13386401428479, 'cvMLD': 0.1323895341879749, 'ecdf': 0.13165383185812624}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 32
# cvMDL: {'exp_rate': 353, 'model': [2, 4], 'sample_rate': 3106}
# L2 error: {'cvMLD': 9.538189475785198e-05, 'ecdf': 0.0001972858397927036}
# VaR: {'oracle': array(2.65082319), 'cvMLD': array(2.65312525), 'ecdf': array(2.66547333)}
# CVaR: {'oracle': 2.6802907910148286, 'cvMLD': 2.673884456731751, 'ecdf': 2.6952435723713015}
# CVaR2: {'oracle': 2.620671288713193, 'cvMLD': 2.6214729157963377, 'ecdf': 2.627259150988366}
# mean: {'oracle': 2.3491619692503622, 'cvMLD': 2.3448598219213226, 'ecdf': 2.340951212983977}
# std: {'oracle': 0.133532362771528, 'cvMLD': 0.13389179513997204, 'ecdf': 0.1346577031676337}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 33
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 7.300677736149554e-05, 'ecdf': 0.00012925896717066787}
# VaR: {'oracle': array(2.65092517), 'cvMLD': array(2.64259812), 'ecdf': array(2.66383576)}
# CVaR: {'oracle': 2.680898909739041, 'cvMLD': 2.6845405940610987, 'ecdf': 2.697318421293783}
# CVaR2: {'oracle': 2.61945704847766, 'cvMLD': 2.629788932392697, 'ecdf': 2.6403985250401982}
# mean: {'oracle': 2.3481802724441034, 'cvMLD': 2.350960534699274, 'ecdf': 2.353998722889751}
# std: {'oracle': 0.1339321674181305, 'cvMLD': 0.13315513463769799, 'ecdf': 0.1323134091591936}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 34
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 7.727743145364531e-05, 'ecdf': 8.213192842455317e-05}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.64462205), 'ecdf': array(2.65862353)}
# CVaR: {'oracle': 2.681010283083812, 'cvMLD': 2.6892895568516604, 'ecdf': 2.7001537615518454}
# CVaR2: {'oracle': 2.6205500078009534, 'cvMLD': 2.625281735041034, 'ecdf': 2.63294873746434}
# mean: {'oracle': 2.3485647650656887, 'cvMLD': 2.3455436937682235, 'ecdf': 2.348800661898716}
# std: {'oracle': 0.13354141918098522, 'cvMLD': 0.13414533842500836, 'ecdf': 0.13706210216580553}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 35
# cvMDL: {'exp_rate': 366, 'model': [2], 'sample_rate': 4282}
# L2 error: {'cvMLD': 5.723123058352939e-05, 'ecdf': 0.0001328289221439095}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.65071125), 'ecdf': array(2.64404177)}
# CVaR: {'oracle': 2.684257795133859, 'cvMLD': 2.6718679093687157, 'ecdf': 2.660656983672526}
# CVaR2: {'oracle': 2.6227040688913212, 'cvMLD': 2.615729266825038, 'ecdf': 2.6116082727942085}
# mean: {'oracle': 2.349351615366154, 'cvMLD': 2.3450317901069595, 'ecdf': 2.342806664741011}
# std: {'oracle': 0.1335963280082201, 'cvMLD': 0.1336679914962991, 'ecdf': 0.1356074072620843}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 36
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 6.305632110227204e-05, 'ecdf': 0.00011125887481869844}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.63495115), 'ecdf': array(2.63376735)}
# CVaR: {'oracle': 2.6828295792550523, 'cvMLD': 2.6629021563286983, 'ecdf': 2.672937331630558}
# CVaR2: {'oracle': 2.622911818367065, 'cvMLD': 2.6142169356713816, 'ecdf': 2.6032845828076776}
# mean: {'oracle': 2.3490878741175805, 'cvMLD': 2.346630356635072, 'ecdf': 2.3450123732891495}
# std: {'oracle': 0.13390708294451165, 'cvMLD': 0.1363085955382251, 'ecdf': 0.130604369917837}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 37
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 8.004955644340327e-05, 'ecdf': 0.00021256712224090556}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.64816286), 'ecdf': array(2.63868802)}
# CVaR: {'oracle': 2.6817655754841843, 'cvMLD': 2.6965571676264175, 'ecdf': 2.690090412723147}
# CVaR2: {'oracle': 2.6218691650908075, 'cvMLD': 2.629494400147796, 'ecdf': 2.620570377692706}
# mean: {'oracle': 2.349077541240256, 'cvMLD': 2.349759569525076, 'ecdf': 2.341645180127108}
# std: {'oracle': 0.13348845528621034, 'cvMLD': 0.13570054028487805, 'ecdf': 0.13612831902501138}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 38
# cvMDL: {'exp_rate': 347, 'model': [2, 4], 'sample_rate': 3423}
# L2 error: {'cvMLD': 9.51040622794489e-05, 'ecdf': 0.00010420918796261435}
# VaR: {'oracle': array(2.65064663), 'cvMLD': array(2.67506423), 'ecdf': array(2.66528359)}
# CVaR: {'oracle': 2.680980458718715, 'cvMLD': 2.6870316346389536, 'ecdf': 2.6931366491954485}
# CVaR2: {'oracle': 2.620478973781648, 'cvMLD': 2.6276770332910484, 'ecdf': 2.6334947085148843}
# mean: {'oracle': 2.347764179494607, 'cvMLD': 2.3496267991423987, 'ecdf': 2.352356449968986}
# std: {'oracle': 0.13338347628980854, 'cvMLD': 0.13688233453624454, 'ecdf': 0.1360908041725766}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 39
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 0.00011171493743444266, 'ecdf': 0.0003827838037912923}
# VaR: {'oracle': array(2.65323579), 'cvMLD': array(2.64273242), 'ecdf': array(2.63887739)}
# CVaR: {'oracle': 2.682986804418939, 'cvMLD': 2.6706952111289763, 'ecdf': 2.6681773559624777}
# CVaR2: {'oracle': 2.6219362803761865, 'cvMLD': 2.619050798226274, 'ecdf': 2.615456407048784}
# mean: {'oracle': 2.347935314306173, 'cvMLD': 2.3515537600787852, 'ecdf': 2.356888999016304}
# std: {'oracle': 0.13339273313262845, 'cvMLD': 0.13491915549476666, 'ecdf': 0.1372799034812875}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 40
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 4.616383474624485e-05, 'ecdf': 0.000129046326966138}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.65495272), 'ecdf': array(2.65009781)}
# CVaR: {'oracle': 2.684151407099032, 'cvMLD': 2.6812967360799265, 'ecdf': 2.6627051014815226}
# CVaR2: {'oracle': 2.6224025825668384, 'cvMLD': 2.625992808572748, 'ecdf': 2.612091441315523}
# mean: {'oracle': 2.3491039215423233, 'cvMLD': 2.3465140307942813, 'ecdf': 2.3422084663647844}
# std: {'oracle': 0.13386375683530696, 'cvMLD': 0.13465639479245473, 'ecdf': 0.13108706909373866}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 41
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 6.892121361699134e-05, 'ecdf': 0.00015738050351087613}
# VaR: {'oracle': array(2.65134298), 'cvMLD': array(2.66234559), 'ecdf': array(2.65375973)}
# CVaR: {'oracle': 2.6831518787159716, 'cvMLD': 2.683993974693009, 'ecdf': 2.674892072592983}
# CVaR2: {'oracle': 2.62121641425265, 'cvMLD': 2.6322933327544438, 'ecdf': 2.6267419134287167}
# mean: {'oracle': 2.348470230567044, 'cvMLD': 2.3487260055909136, 'ecdf': 2.3487885394365104}
# std: {'oracle': 0.13342367798395802, 'cvMLD': 0.13524224955354996, 'ecdf': 0.1387983817864877}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 42
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 7.99163151603255e-05, 'ecdf': 5.129171143075275e-05}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.62835181), 'ecdf': array(2.6539958)}
# CVaR: {'oracle': 2.6821514405231217, 'cvMLD': 2.673195028070242, 'ecdf': 2.687105695025731}
# CVaR2: {'oracle': 2.6223311881215947, 'cvMLD': 2.607422514537828, 'ecdf': 2.6100948546323197}
# mean: {'oracle': 2.348883016066005, 'cvMLD': 2.34508673687771, 'ecdf': 2.3458652891247493}
# std: {'oracle': 0.1337543786552932, 'cvMLD': 0.1308000876918724, 'ecdf': 0.13170246811237327}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 43
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 7.94375482094065e-05, 'ecdf': 0.0002358205213804333}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.65640203), 'ecdf': array(2.63761008)}
# CVaR: {'oracle': 2.6834722600299687, 'cvMLD': 2.6676510138506186, 'ecdf': 2.662330672757804}
# CVaR2: {'oracle': 2.623109011165929, 'cvMLD': 2.6108786097507837, 'ecdf': 2.597362988109778}
# mean: {'oracle': 2.3492420394458655, 'cvMLD': 2.3498549141639233, 'ecdf': 2.343165526627223}
# std: {'oracle': 0.13431861553595287, 'cvMLD': 0.13100348440616102, 'ecdf': 0.12505979300211226}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 44
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 0.00010272756361077817, 'ecdf': 0.00016369226640592768}
# VaR: {'oracle': array(2.65042067), 'cvMLD': array(2.6522107), 'ecdf': array(2.67886396)}
# CVaR: {'oracle': 2.67956167409112, 'cvMLD': 2.6950044021277795, 'ecdf': 2.711332137152809}
# CVaR2: {'oracle': 2.6193061390101087, 'cvMLD': 2.622051497313418, 'ecdf': 2.646815672311616}
# mean: {'oracle': 2.3489426372780104, 'cvMLD': 2.348421182406023, 'ecdf': 2.3454023730959226}
# std: {'oracle': 0.13296262851208512, 'cvMLD': 0.1363430926725334, 'ecdf': 0.14070976878977462}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 45
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 8.786503286823729e-05, 'ecdf': 9.913149813053916e-05}
# VaR: {'oracle': array(2.65437726), 'cvMLD': array(2.63088855), 'ecdf': array(2.61956834)}
# CVaR: {'oracle': 2.6816208292809227, 'cvMLD': 2.6678910818653794, 'ecdf': 2.679330702421179}
# CVaR2: {'oracle': 2.6229717084990587, 'cvMLD': 2.606984398749753, 'ecdf': 2.607625397678824}
# mean: {'oracle': 2.3490301592751077, 'cvMLD': 2.3452300087687754, 'ecdf': 2.346672754784672}
# std: {'oracle': 0.13338490921426202, 'cvMLD': 0.1343386050820575, 'ecdf': 0.13729568527287656}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 46
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 9.53982114733154e-05, 'ecdf': 0.00015255917792825942}
# VaR: {'oracle': array(2.65036809), 'cvMLD': array(2.66125542), 'ecdf': array(2.68533121)}
# CVaR: {'oracle': 2.678487463756524, 'cvMLD': 2.6853487425535674, 'ecdf': 2.715624742590816}
# CVaR2: {'oracle': 2.620499551514882, 'cvMLD': 2.6174517569789018, 'ecdf': 2.635648370078092}
# mean: {'oracle': 2.3489039797373654, 'cvMLD': 2.345838917375195, 'ecdf': 2.344589121892721}
# std: {'oracle': 0.1337519178872379, 'cvMLD': 0.1315024468785407, 'ecdf': 0.1329448795056473}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 47
# cvMDL: {'exp_rate': 346, 'model': [2, 4], 'sample_rate': 3476}
# L2 error: {'cvMLD': 0.00014831612753163584, 'ecdf': 0.00011083304299618784}
# VaR: {'oracle': array(2.65008955), 'cvMLD': array(2.65908403), 'ecdf': array(2.665179)}
# CVaR: {'oracle': 2.682403813045827, 'cvMLD': 2.678434342317058, 'ecdf': 2.6782507818293086}
# CVaR2: {'oracle': 2.620737922976386, 'cvMLD': 2.623116159339115, 'ecdf': 2.63022392727933}
# mean: {'oracle': 2.348186884083448, 'cvMLD': 2.352847429319116, 'ecdf': 2.3516267327635014}
# std: {'oracle': 0.133177643196603, 'cvMLD': 0.13530236243135105, 'ecdf': 0.13936753740668248}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 48
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 7.324531650546682e-05, 'ecdf': 0.00011743778579921204}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.66014165), 'ecdf': array(2.64336873)}
# CVaR: {'oracle': 2.6838929047088933, 'cvMLD': 2.6728219377626523, 'ecdf': 2.659564759041672}
# CVaR2: {'oracle': 2.622637771499213, 'cvMLD': 2.616620283126882, 'ecdf': 2.6064098314515105}
# mean: {'oracle': 2.3488904014521688, 'cvMLD': 2.3476679876331437, 'ecdf': 2.3427149046596476}
# std: {'oracle': 0.1339959735209697, 'cvMLD': 0.13179966245643723, 'ecdf': 0.13036397615408163}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 49
# cvMDL: {'exp_rate': 365, 'model': [2], 'sample_rate': 4376}
# L2 error: {'cvMLD': 0.000147760032830432, 'ecdf': 0.0002282482509212556}
# VaR: {'oracle': array(2.65036809), 'cvMLD': array(2.64237629), 'ecdf': array(2.67569078)}
# CVaR: {'oracle': 2.678928743272886, 'cvMLD': 2.687943082200983, 'ecdf': 2.697584507722788}
# CVaR2: {'oracle': 2.6200788849746237, 'cvMLD': 2.623064057412946, 'ecdf': 2.634295745587114}
# mean: {'oracle': 2.3486848911354348, 'cvMLD': 2.343457558813445, 'ecdf': 2.3471097375623633}
# std: {'oracle': 0.13314962308764028, 'cvMLD': 0.13731263030614776, 'ecdf': 0.13990210899044023}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 50
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 0.00011379972815058719, 'ecdf': 7.949395784914406e-05}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.64481185), 'ecdf': array(2.65896649)}
# CVaR: {'oracle': 2.681634727059043, 'cvMLD': 2.686508027080305, 'ecdf': 2.692675332075219}
# CVaR2: {'oracle': 2.6218958495271116, 'cvMLD': 2.6122877299673073, 'ecdf': 2.616122743207535}
# mean: {'oracle': 2.348921535101192, 'cvMLD': 2.3488641738709273, 'ecdf': 2.346015592816724}
# std: {'oracle': 0.13392178791798962, 'cvMLD': 0.13238069076496187, 'ecdf': 0.13117462120619158}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 51
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 6.615830435933109e-05, 'ecdf': 5.330423931530283e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.65144332), 'ecdf': array(2.64920186)}
# CVaR: {'oracle': 2.6826619975955963, 'cvMLD': 2.665601738448126, 'ecdf': 2.660822951036355}
# CVaR2: {'oracle': 2.621728144457468, 'cvMLD': 2.624634319263981, 'ecdf': 2.61267080908944}
# mean: {'oracle': 2.3483360414304335, 'cvMLD': 2.3493575285342967, 'ecdf': 2.3507514751485554}
# std: {'oracle': 0.13379362098618244, 'cvMLD': 0.13500474954478384, 'ecdf': 0.12978520632299326}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 52
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 8.038588881502586e-05, 'ecdf': 8.650499147575761e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.6502833), 'ecdf': array(2.64428027)}
# CVaR: {'oracle': 2.683300401596337, 'cvMLD': 2.6741450156451245, 'ecdf': 2.6722946803425836}
# CVaR2: {'oracle': 2.6213811007938688, 'cvMLD': 2.619517702525944, 'ecdf': 2.619488927657888}
# mean: {'oracle': 2.3480668239409113, 'cvMLD': 2.347620439713617, 'ecdf': 2.3528324144400683}
# std: {'oracle': 0.1337964498367591, 'cvMLD': 0.13220740616342067, 'ecdf': 0.13262621750425901}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 53
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 0.00010060988106011839, 'ecdf': 0.0003412981948611683}
# VaR: {'oracle': array(2.65120371), 'cvMLD': array(2.65069968), 'ecdf': array(2.65831373)}
# CVaR: {'oracle': 2.682196101617487, 'cvMLD': 2.675214125196931, 'ecdf': 2.685080846112403}
# CVaR2: {'oracle': 2.620832041459689, 'cvMLD': 2.6200261896444466, 'ecdf': 2.6308895814512043}
# mean: {'oracle': 2.3491152730995615, 'cvMLD': 2.3480873205954302, 'ecdf': 2.340838566848282}
# std: {'oracle': 0.1336097620522543, 'cvMLD': 0.13425540071487913, 'ecdf': 0.13589771764999323}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 54
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 9.081101581740133e-05, 'ecdf': 0.00011087047759705614}
# VaR: {'oracle': array(2.65426766), 'cvMLD': array(2.61763539), 'ecdf': array(2.61712511)}
# CVaR: {'oracle': 2.684333912812586, 'cvMLD': 2.6543202124138596, 'ecdf': 2.6381024409801133}
# CVaR2: {'oracle': 2.62351426826742, 'cvMLD': 2.6086320093034248, 'ecdf': 2.596588407034319}
# mean: {'oracle': 2.3488425140933087, 'cvMLD': 2.3470962240101887, 'ecdf': 2.3461070151199994}
# std: {'oracle': 0.13397771789867502, 'cvMLD': 0.13240289862944418, 'ecdf': 0.1309558811459685}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 55
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 8.776151342323836e-05, 'ecdf': 0.0006562527673060053}
# VaR: {'oracle': array(2.65188415), 'cvMLD': array(2.66796033), 'ecdf': array(2.62031535)}
# CVaR: {'oracle': 2.6822710739868016, 'cvMLD': 2.6871001618029564, 'ecdf': 2.6766598796939864}
# CVaR2: {'oracle': 2.622668772474986, 'cvMLD': 2.6200469889848264, 'ecdf': 2.5971567337202526}
# mean: {'oracle': 2.3498451322137037, 'cvMLD': 2.3471843137915043, 'ecdf': 2.3348743816480866}
# std: {'oracle': 0.13435488973668633, 'cvMLD': 0.13335477435779977, 'ecdf': 0.12509283640060562}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 56
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 6.800108118534587e-05, 'ecdf': 0.00014905123493743003}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.64694845), 'ecdf': array(2.64824533)}
# CVaR: {'oracle': 2.682859260315144, 'cvMLD': 2.6650681386229875, 'ecdf': 2.6747640646597226}
# CVaR2: {'oracle': 2.6211555145747254, 'cvMLD': 2.611356920358193, 'ecdf': 2.6238257424818254}
# mean: {'oracle': 2.3490506655003034, 'cvMLD': 2.34655987033676, 'ecdf': 2.344735611178155}
# std: {'oracle': 0.13363405953113042, 'cvMLD': 0.13255575723970325, 'ecdf': 0.13524498268022708}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 57
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 0.00012674092986428558, 'ecdf': 0.00015210075220805267}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.65503375), 'ecdf': array(2.65882743)}
# CVaR: {'oracle': 2.6833505758671636, 'cvMLD': 2.6792995539412843, 'ecdf': 2.6719779624368645}
# CVaR2: {'oracle': 2.622188016891011, 'cvMLD': 2.6214112540133727, 'ecdf': 2.615217755378217}
# mean: {'oracle': 2.349066383002015, 'cvMLD': 2.350864753867438, 'ecdf': 2.3463633750002817}
# std: {'oracle': 0.1341954165322385, 'cvMLD': 0.1303427104492303, 'ecdf': 0.1275478533995928}
# -------------------------------------------------------------------------------------------------------------
# ...
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 81
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 3.7982461068057814e-05, 'ecdf': 0.0002626943224550983}
# VaR: {'oracle': array(2.65064663), 'cvMLD': array(2.64963547), 'ecdf': array(2.66560432)}
# CVaR: {'oracle': 2.680373309821764, 'cvMLD': 2.6842800893516947, 'ecdf': 2.6863192796526163}
# CVaR2: {'oracle': 2.6212939881164554, 'cvMLD': 2.6162796524661247, 'ecdf': 2.6161855525705913}
# mean: {'oracle': 2.3481125139470977, 'cvMLD': 2.349060353803691, 'ecdf': 2.352144353261625}
# std: {'oracle': 0.13418445808174126, 'cvMLD': 0.1320271781689244, 'ecdf': 0.12652729549833777}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 82
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 0.00010953043799160929, 'ecdf': 8.551368422056959e-05}
# VaR: {'oracle': array(2.65426766), 'cvMLD': array(2.62820614), 'ecdf': array(2.63872065)}
# CVaR: {'oracle': 2.683103154788887, 'cvMLD': 2.672328334174445, 'ecdf': 2.67101329271895}
# CVaR2: {'oracle': 2.622021839138554, 'cvMLD': 2.618130821557787, 'ecdf': 2.615377694463424}
# mean: {'oracle': 2.348663782859386, 'cvMLD': 2.349024681214432, 'ecdf': 2.347511998147928}
# std: {'oracle': 0.13404808479735775, 'cvMLD': 0.1342368336243436, 'ecdf': 0.1306612063336542}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 83
# cvMDL: {'exp_rate': 352, 'model': [2, 4], 'sample_rate': 3159}
# L2 error: {'cvMLD': 5.745894711695874e-05, 'ecdf': 0.00010013725111001832}
# VaR: {'oracle': array(2.65160713), 'cvMLD': array(2.62803237), 'ecdf': array(2.65184992)}
# CVaR: {'oracle': 2.681142867107256, 'cvMLD': 2.6712253386171207, 'ecdf': 2.6997189784758704}
# CVaR2: {'oracle': 2.6217845854252135, 'cvMLD': 2.619225925525058, 'ecdf': 2.61796786330405}
# mean: {'oracle': 2.3484871562487073, 'cvMLD': 2.34558713140776, 'ecdf': 2.348658571438167}
# std: {'oracle': 0.13355745553910287, 'cvMLD': 0.13376361592460217, 'ecdf': 0.133927636661974}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 84
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 7.854423557442384e-05, 'ecdf': 7.695557240303872e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.63621093), 'ecdf': array(2.6316547)}
# CVaR: {'oracle': 2.684090345303878, 'cvMLD': 2.659104537342329, 'ecdf': 2.658273292841138}
# CVaR2: {'oracle': 2.622135972081902, 'cvMLD': 2.615360199980716, 'ecdf': 2.617912110228978}
# mean: {'oracle': 2.348684918225078, 'cvMLD': 2.3473939746047408, 'ecdf': 2.3493331823807715}
# std: {'oracle': 0.13412173472902594, 'cvMLD': 0.13242650788841454, 'ecdf': 0.13126053476717559}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 85
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 6.0955499815746816e-05, 'ecdf': 0.00010689051265517364}
# VaR: {'oracle': array(2.65148225), 'cvMLD': array(2.65577205), 'ecdf': array(2.66377638)}
# CVaR: {'oracle': 2.6830317414688065, 'cvMLD': 2.6794983879467353, 'ecdf': 2.6753539269023503}
# CVaR2: {'oracle': 2.6215627254909855, 'cvMLD': 2.6225886955341804, 'ecdf': 2.6244208787231758}
# mean: {'oracle': 2.348888103819343, 'cvMLD': 2.349177044630679, 'ecdf': 2.3467056634421812}
# std: {'oracle': 0.13388075537650185, 'cvMLD': 0.134702779971541, 'ecdf': 0.13155597889942078}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 86
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 0.00010389027677718725, 'ecdf': 0.00017730212024818262}
# VaR: {'oracle': array(2.65092517), 'cvMLD': array(2.6773218), 'ecdf': array(2.68414444)}
# CVaR: {'oracle': 2.679729440681587, 'cvMLD': 2.6908805567295064, 'ecdf': 2.7057554363962097}
# CVaR2: {'oracle': 2.6206695152588266, 'cvMLD': 2.625865281626938, 'ecdf': 2.6360244522989627}
# mean: {'oracle': 2.3492128648681208, 'cvMLD': 2.3454865811782923, 'ecdf': 2.3423491716046265}
# std: {'oracle': 0.13345041368526792, 'cvMLD': 0.13429923737867122, 'ecdf': 0.138057809161745}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 87
# cvMDL: {'exp_rate': 348, 'model': [2, 4], 'sample_rate': 3370}
# L2 error: {'cvMLD': 7.532219149841297e-05, 'ecdf': 0.00023695730533315084}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.6510027), 'ecdf': array(2.65115325)}
# CVaR: {'oracle': 2.6803062359440752, 'cvMLD': 2.690833968137208, 'ecdf': 2.709140116649639}
# CVaR2: {'oracle': 2.620980109209259, 'cvMLD': 2.6261050682923908, 'ecdf': 2.628868250353192}
# mean: {'oracle': 2.3491032392679143, 'cvMLD': 2.3514520086570503, 'ecdf': 2.342909304893767}
# std: {'oracle': 0.13335389105990525, 'cvMLD': 0.13097040792539585, 'ecdf': 0.1374841201716185}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 88
# cvMDL: {'exp_rate': 353, 'model': [2, 4], 'sample_rate': 3106}
# L2 error: {'cvMLD': 0.0001246648050869054, 'ecdf': 8.014394635294346e-05}
# VaR: {'oracle': array(2.65133012), 'cvMLD': array(2.65086743), 'ecdf': array(2.67309284)}
# CVaR: {'oracle': 2.6803563828649497, 'cvMLD': 2.6773063077556056, 'ecdf': 2.7043116762237482}
# CVaR2: {'oracle': 2.6203066701863205, 'cvMLD': 2.6285483726056036, 'ecdf': 2.6349627557535116}
# mean: {'oracle': 2.348304316555084, 'cvMLD': 2.3503422208789098, 'ecdf': 2.3505201779641562}
# std: {'oracle': 0.13355860416946186, 'cvMLD': 0.1329220412975667, 'ecdf': 0.13381327128059084}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 89
# cvMDL: {'exp_rate': 347, 'model': [2, 4], 'sample_rate': 3423}
# L2 error: {'cvMLD': 8.324696712237393e-05, 'ecdf': 8.65628198188824e-05}
# VaR: {'oracle': array(2.65092517), 'cvMLD': array(2.66306552), 'ecdf': array(2.68479228)}
# CVaR: {'oracle': 2.679972302823693, 'cvMLD': 2.7005334200304687, 'ecdf': 2.7052354169640256}
# CVaR2: {'oracle': 2.6191620842102448, 'cvMLD': 2.6350524526778543, 'ecdf': 2.646896416815129}
# mean: {'oracle': 2.348305746288017, 'cvMLD': 2.352586543962786, 'ecdf': 2.3530399594573965}
# std: {'oracle': 0.13341244525804485, 'cvMLD': 0.13421311759559645, 'ecdf': 0.13708626167778973}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 90
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 5.5893176197106915e-05, 'ecdf': 9.665435302081497e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.63727558), 'ecdf': array(2.63159127)}
# CVaR: {'oracle': 2.682754249108409, 'cvMLD': 2.678814982209261, 'ecdf': 2.6693363986642646}
# CVaR2: {'oracle': 2.6222787507792593, 'cvMLD': 2.617306692782647, 'ecdf': 2.6107837873262794}
# mean: {'oracle': 2.348878882938341, 'cvMLD': 2.3475759724883187, 'ecdf': 2.347120864889096}
# std: {'oracle': 0.13346715987602545, 'cvMLD': 0.13599357325012332, 'ecdf': 0.1354444830199957}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 91
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 0.00011263635704869738, 'ecdf': 0.0003538042970177991}
# VaR: {'oracle': array(2.65134298), 'cvMLD': array(2.63820651), 'ecdf': array(2.658352)}
# CVaR: {'oracle': 2.682316450821504, 'cvMLD': 2.6645379435734844, 'ecdf': 2.6844621665531343}
# CVaR2: {'oracle': 2.6204637616367874, 'cvMLD': 2.614739908964017, 'ecdf': 2.630296966269954}
# mean: {'oracle': 2.347365892635508, 'cvMLD': 2.352553539641247, 'ecdf': 2.360181554374339}
# std: {'oracle': 0.13349006096851138, 'cvMLD': 0.13283790775775187, 'ecdf': 0.134978009669048}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 92
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 8.704854050596161e-05, 'ecdf': 0.00013166545437313484}
# VaR: {'oracle': array(2.65105311), 'cvMLD': array(2.64164114), 'ecdf': array(2.67107788)}
# CVaR: {'oracle': 2.6804124613899165, 'cvMLD': 2.6775958283517527, 'ecdf': 2.7018826318761886}
# CVaR2: {'oracle': 2.6211568632681135, 'cvMLD': 2.6146108921290345, 'ecdf': 2.6284541124320295}
# mean: {'oracle': 2.348193259250726, 'cvMLD': 2.351227043517523, 'ecdf': 2.3544227725665356}
# std: {'oracle': 0.13354286107725435, 'cvMLD': 0.13512116414602765, 'ecdf': 0.13728682635818248}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 93
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 8.121401393596204e-05, 'ecdf': 9.317941345956674e-05}
# VaR: {'oracle': array(2.65343204), 'cvMLD': array(2.6681995), 'ecdf': array(2.63774306)}
# CVaR: {'oracle': 2.6824799569549826, 'cvMLD': 2.704030303343956, 'ecdf': 2.6794938599426366}
# CVaR2: {'oracle': 2.622099749736455, 'cvMLD': 2.6250744094440757, 'ecdf': 2.612220600704017}
# mean: {'oracle': 2.348981233903163, 'cvMLD': 2.348205220867379, 'ecdf': 2.3440019028069248}
# std: {'oracle': 0.13366402608086964, 'cvMLD': 0.1340560706394743, 'ecdf': 0.13474242094913266}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 94
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 5.2275056854207963e-05, 'ecdf': 0.00018125886021134904}
# VaR: {'oracle': array(2.65092517), 'cvMLD': array(2.65096374), 'ecdf': array(2.66846767)}
# CVaR: {'oracle': 2.6799879689985655, 'cvMLD': 2.677772769953892, 'ecdf': 2.6885930655775985}
# CVaR2: {'oracle': 2.6209694598756617, 'cvMLD': 2.6222103416051987, 'ecdf': 2.6177375645874212}
# mean: {'oracle': 2.3489378812882316, 'cvMLD': 2.3475286363010768, 'ecdf': 2.3416619346203236}
# std: {'oracle': 0.13375911267590454, 'cvMLD': 0.13552264716421747, 'ecdf': 0.1316100603029534}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 95
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 8.022349659547848e-05, 'ecdf': 0.00011542345061896232}
# VaR: {'oracle': array(2.65426766), 'cvMLD': array(2.62297811), 'ecdf': array(2.6183572)}
# CVaR: {'oracle': 2.682646815229854, 'cvMLD': 2.654597805282629, 'ecdf': 2.637941083392311}
# CVaR2: {'oracle': 2.623161004697757, 'cvMLD': 2.60595853901037, 'ecdf': 2.593068963904381}
# mean: {'oracle': 2.348601571428909, 'cvMLD': 2.3503256888366755, 'ecdf': 2.346364706684764}
# std: {'oracle': 0.1341650603147777, 'cvMLD': 0.1309847187667428, 'ecdf': 0.1264752152622557}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 96
# cvMDL: {'exp_rate': 350, 'model': [2, 4], 'sample_rate': 3265}
# L2 error: {'cvMLD': 0.00016150925200513353, 'ecdf': 0.00012593471297386318}
# VaR: {'oracle': array(2.65468547), 'cvMLD': array(2.6237014), 'ecdf': array(2.62107293)}
# CVaR: {'oracle': 2.684595944515042, 'cvMLD': 2.6452916186389923, 'ecdf': 2.645622066105959}
# CVaR2: {'oracle': 2.624042515037961, 'cvMLD': 2.598607773726229, 'ecdf': 2.586708196097396}
# mean: {'oracle': 2.3492859517451725, 'cvMLD': 2.347009276659987, 'ecdf': 2.342391357537309}
# std: {'oracle': 0.1340339692134743, 'cvMLD': 0.12882073213918124, 'ecdf': 0.12905548930672212}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 97
# cvMDL: {'exp_rate': 351, 'model': [2, 4], 'sample_rate': 3212}
# L2 error: {'cvMLD': 5.1350418076529425e-05, 'ecdf': 0.00038136801093306}
# VaR: {'oracle': array(2.65064663), 'cvMLD': array(2.65457185), 'ecdf': array(2.68684487)}
# CVaR: {'oracle': 2.6793254160857907, 'cvMLD': 2.690312239336199, 'ecdf': 2.703038435670152}
# CVaR2: {'oracle': 2.6211811979273945, 'cvMLD': 2.625219530519756, 'ecdf': 2.6250285194583656}
# mean: {'oracle': 2.3496986063076255, 'cvMLD': 2.3473132311225147, 'ecdf': 2.338726560760751}
# std: {'oracle': 0.13396000745223552, 'cvMLD': 0.13424460138588018, 'ecdf': 0.1317994442139017}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 98
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 5.088736923972437e-05, 'ecdf': 7.964783403858839e-05}
# VaR: {'oracle': array(2.65064663), 'cvMLD': array(2.65922628), 'ecdf': array(2.65923906)}
# CVaR: {'oracle': 2.6828493237184374, 'cvMLD': 2.6824033554107176, 'ecdf': 2.67546039955964}
# CVaR2: {'oracle': 2.6214399642901354, 'cvMLD': 2.6320092893054405, 'ecdf': 2.6259863966153163}
# mean: {'oracle': 2.3486721856024566, 'cvMLD': 2.3493023662752406, 'ecdf': 2.348472625640509}
# std: {'oracle': 0.13357814907504847, 'cvMLD': 0.13350661877376524, 'ecdf': 0.1359792316874409}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------
# i = 99
# cvMDL: {'exp_rate': 349, 'model': [2, 4], 'sample_rate': 3318}
# L2 error: {'cvMLD': 9.550083025727049e-05, 'ecdf': 0.0003389096881979148}
# VaR: {'oracle': array(2.65176079), 'cvMLD': array(2.65545349), 'ecdf': array(2.65130439)}
# CVaR: {'oracle': 2.681658912932473, 'cvMLD': 2.6855430000456977, 'ecdf': 2.692823893592905}
# CVaR2: {'oracle': 2.621653769782136, 'cvMLD': 2.622753076118188, 'ecdf': 2.6144372845520145}
# mean: {'oracle': 2.3477807750964472, 'cvMLD': 2.350110419407058, 'ecdf': 2.3567252170910105}
# std: {'oracle': 0.13420278047287823, 'cvMLD': 0.13335289831147998, 'ecdf': 0.1274970283843846}
# -------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Get average exploration rate

# %%
print('Average exploration rate:', cvMDL_exp/N)
# Out:
# Average exploration rate: 350.0

# %% [markdown]
# ## Get mean relative errors

# %%
cvMDL_cvar_error = abs(np.array(cvMDL_cvar)-np.array(oracle_cvar))/np.array(oracle_cvar)
ecdf_cvar_error = abs(np.array(ecdf_cvar)-np.array(oracle_cvar))/np.array(oracle_cvar)
cvMDL_cvar2_error = abs(np.array(cvMDL_cvar2)-np.array(oracle_cvar2))/np.array(oracle_cvar2)
ecdf_cvar2_error = abs(np.array(ecdf_cvar2)-np.array(oracle_cvar2))/np.array(oracle_cvar2)
cvMDL_mean_error = abs(np.array(cvMDL_mean)-np.array(oracle_mean))/np.array(oracle_mean)
ecdf_mean_error = abs(np.array(ecdf_mean)-np.array(oracle_mean))/np.array(oracle_mean)
cvMDL_sd_error = abs(np.array(cvMDL_sd)-np.array(oracle_sd))/np.array(oracle_sd)
ecdf_sd_error = abs(np.array(ecdf_sd)-np.array(oracle_sd))/np.array(oracle_sd)
print('L2 error: {}'.format({key: value for key, value in zip(['cvMLD', 'ecdf'], [np.mean(cvMDL_l2), np.mean(ecdf_l2)])}))
print('CVaR error: {}'.format({key: value for key, value in zip(['cvMLD', 'ecdf'], [np.mean(cvMDL_cvar_error), np.mean(ecdf_cvar_error)])}))
print('CVaR2 error: {}'.format({key: value for key, value in zip(['cvMLD', 'ecdf'], [np.mean(cvMDL_cvar2_error), np.mean(ecdf_cvar2_error)])}))                                                   
print('Mean error: {}'.format({key: value for key, value in zip(['cvMLD', 'ecdf'], [np.mean(cvMDL_mean_error), np.mean(ecdf_mean_error)])}))                                                                                  
print('Standard deviation error: {}'.format({key: value for key, value in zip(['cvMLD', 'ecdf'], [np.mean(cvMDL_sd_error), np.mean(ecdf_sd_error)])}))
# Out:
# L2 error: {'cvMLD': 8.441393293942907e-05, 'ecdf': 0.0001627287384578072}
# CVaR error: {'cvMLD': 0.004845892058662247, 'ecdf': 0.0071024677345338325}
# CVaR2 error: {'cvMLD': 0.0026068164436175577, 'ecdf': 0.00447059421052513}
# Mean error: {'cvMLD': 0.0008956662930594641, 'ecdf': 0.001983342678560132}
# Standard deviation error: {'cvMLD': 0.013400958089323945, 'ecdf': 0.026697863691216246}

# %% [markdown]
# ## Demonstration of the last instance of cvMLD and ECDF

# %%
plt.figure(figsize=(22, 10*(24/12)))
plt.plot(III, y_oracle(III), linewidth= 12, color = 'gray', label = 'Oracle')
plt.plot(III, [cvMDL_exploit['cdf'](x) for x in III], linewidth = 10, color = 'red',  linestyle='--',label = 'cvMDL*-sorted')
plt.plot(III, ecdf(III), linewidth = 6, color = 'black', label = 'ECDF')

# Enable LaTeX rendering
rc('text', usetex=True)
# Set the desired font family
rc('font', family='serif')

plt.xlabel('QoI (x$10^6$ N)', size = 32*2.0)
plt.ylabel('CDF', size = 32*2.0)
plt.xticks(size = 32*2.0)
plt.yticks(size = 32*2.0)
plt.legend(fontsize = 32*2.0)

if not os.path.exists(foldername):
    os.makedirs(foldername)
plt.savefig(f"./{foldername}/brittle_cdf.pdf", dpi=600)

# %% [markdown]
# ## Boxplot of CVaR

# %%
if not os.path.exists(foldername):
    os.makedirs(foldername)

data = [oracle_cvar, ecdf_cvar, cvMDL_cvar]

# ax.axhline(y=oracle_cvar[0],linestyle =':' ,color='black', label = 'Oracle')
#ax.set_ylim(2.58,2.68)
fig, ax = plt.subplots(figsize=(22, 10*(24/12)))
box = ax.boxplot(data, patch_artist=False, medianprops=dict(color='black', linewidth=2*4))
plt.xticks(size = 32*2.0)
plt.yticks(size = 32*2.0)

# Enable LaTeX rendering
rc('text', usetex=True)
# Set the desired font family
rc('font', family='serif')

ax.set_ylabel('0.99 CVaR (x$10^6$ N)', fontsize=32*2.0) # Add y-axis label
# Adding x-tick labels
xticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
yticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
ax.set_xticklabels(xticklabels)
colors = ['blue', 'green', 'red']
for i, datat in enumerate(data):
    x = np.random.normal(i + 1, 0.04, size=len(datat))
    ax.scatter(x, datat, color = colors[i], alpha=0.7, s = 420)
plt.subplots_adjust(left=0.2, bottom=0.15)
plt.savefig(f"./{foldername}/brittle_cvar0.99.pdf", dpi=600)

# %%
if not os.path.exists(foldername):
    os.makedirs(foldername)

data = [oracle_cvar2, ecdf_cvar2, cvMDL_cvar2]

# ax.axhline(y=oracle_cvar[0],linestyle =':' ,color='black', label = 'Oracle')
#ax.set_ylim(2.58,2.68)
fig, ax = plt.subplots(figsize=(22, 10*(24/12)))
box = ax.boxplot(data, patch_artist=False, medianprops=dict(color='black', linewidth=2*4))
plt.xticks(size = 32*2.0)
plt.yticks(size = 32*2.0)

# Enable LaTeX rendering
rc('text', usetex=True)
# Set the desired font family
rc('font', family='serif')


ax.set_ylabel('0.95 CVaR (x$10^6$ N)', fontsize=32*2.0) # Add y-axis label
# Adding x-tick labels
xticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
yticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
ax.set_xticklabels(xticklabels)
colors = ['blue', 'green', 'red']
for i, datat in enumerate(data):
    x = np.random.normal(i + 1, 0.04, size=len(datat))
    ax.scatter(x, datat, color = colors[i], alpha=0.7, s = 420)
plt.subplots_adjust(left=0.2, bottom=0.15)
plt.savefig(f"./{foldername}/brittle_cvar0.95.pdf", dpi=600)

# %% [markdown]
# ## Boxplot of mean

# %%
if not os.path.exists(foldername):
    os.makedirs(foldername)
    
data = [oracle_mean, ecdf_mean, cvMDL_mean]
fig, ax = plt.subplots(figsize=(22, 10*(24/12)))
box = ax.boxplot(data, patch_artist=False, medianprops=dict(color='black', linewidth=2*4))
plt.xticks(size = 32*2.0)
plt.yticks(size = 32*2.0)
#ax.set_ylim(2.335,2.365)

# Enable LaTeX rendering
rc('text', usetex=True)
# Set the desired font family
rc('font', family='serif')

ax.set_ylabel('Mean of QoI (x$10^6$ N)', fontsize=32*2.0) # Add y-axis label
# Adding x-tick labels
xticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
yticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
ax.set_xticklabels(xticklabels)
colors = ['blue', 'green', 'red']
for i, datat in enumerate(data):
    x = np.random.normal(i + 1, 0.04, size=len(datat))
    ax.scatter(x, datat, color = colors[i], alpha=0.7, s = 420)
plt.subplots_adjust(left=0.2, bottom=0.15)
plt.savefig(f"./{foldername}/brittle_mean.pdf", dpi=600)

# %% [markdown]
# ## Boxplot of standard deviation

# %%
data = [np.array(oracle_sd), np.array(ecdf_sd), np.array(cvMDL_sd)]
fig, ax = plt.subplots(figsize=(22, 10*(24/12)))
box = ax.boxplot(data, patch_artist=False, medianprops=dict(color='black', linewidth=2*4))
plt.xticks(size = 32*2.0)
plt.yticks(size = 32*2.0)
#ax.set_ylim(0.014,0.021)

#eng_formatter = EngFormatter(places=1)  # You can modify the number of decimal places with the places argument
#ax.yaxis.set_major_formatter(eng_formatter)

ax.set_ylabel('SD of QoI (x$10^6$ N)', fontsize=32*2.0) # Add y-axis label
# Adding x-tick labels
xticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
yticklabels = ['Oracle', 'ECDF', 'cvMDL*-sorted']
ax.set_xticklabels(xticklabels)
colors = ['blue', 'green', 'red']
for i, datat in enumerate(data):
    x = np.random.normal(i + 1, 0.04, size=len(datat))
    ax.scatter(x, datat, color = colors[i], alpha=0.7, s = 420)
plt.subplots_adjust(left=0.2, bottom=0.15)
plt.savefig(f"./{foldername}/brittle_sd.pdf", dpi=600)
